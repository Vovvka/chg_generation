# %%
from datetime import datetime, timedelta
#from dateutil.relativedelta import relativedelta
#import pytz
import openpyxl
import pandas as pd


def get_data (output_file_path, row_num):
    
    try:

        workbook = openpyxl.load_workbook(output_file_path)

        # Select the sheet (active by default, modify if you need specific sheet)
        output_sheet = workbook.active

        cr_number_col = get_column_index(output_sheet, "CR number")
        collection_col = get_column_index(output_sheet, "Collection")
        Start_Date_col = get_column_index(output_sheet, "Start Date")
        End_Date_col = get_column_index(output_sheet, "End Date")
        
        # Get data from specified columns in the current row
        cr_number = output_sheet.cell(row=row_num, column=cr_number_col).value
        collection = output_sheet.cell(row=row_num, column=collection_col).value
        Start_Date = output_sheet.cell(row=row_num, column=Start_Date_col).value
        End_Date = output_sheet.cell(row=row_num, column=End_Date_col).value

        parsed_start_date = datetime.strptime (Start_Date, "%I.%M%p").strftime("%m-%d-%Y %H:%M:%S")
        parsed_end_date = datetime.strptime (End_Date, "%I.%M%p").strftime("%m-%d-%Y %H:%M:%S")

        #return parsed_start_date, parsed_end_date, collection
        fill_sfd (collection, input_file_path)

    except Exception as e:
        print(f"An error occurred: {e}")



def get_column_index(sheet, column_name):
    # Get the column index based on the column name
    for col_num in range(1, sheet.max_column + 1):
        if sheet.cell(row=1, column=col_num).value == column_name:
            return col_num
    raise ValueError(f"Column '{column_name}' not found in the sheet")



def fill_sfd (collection, input_file_path):

    data_frame = pd.read_excel(input_file_path, sheet_name='Scheduled for Deployment')

    group_name_filter = collection
    filtered_data = data_frame[data_frame['Group Name'] == group_name_filter]

    for index, row in filtered_data.iterrows():
        row_values = ' - '.join(str(value) for value in row)
        print(row_values)

if __name__ == "__main__":
    
    target_timezone = 'America/Los_Angeles'

    input_file_path = r'C:\Users\pelyu\OneDrive\Рабочий стол\chg\git\UMG - Syxsense Patch Calendar v357.xlsx'
    output_file_path = r'"C:\Users\pelyu\OneDrive\Рабочий стол\chg\git\write_here.xlsx"'

    row_num = int(input("Enter the row: "))

    get_data (output_file_path, row_num)
# Out:
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP047 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP054 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP051 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP001 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVDBS001 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP013 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP075 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP040 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP074 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP122 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP036 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP123 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP125 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP127 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP129 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP133 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP134 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP039 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP052 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP012 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP041 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP048 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP007 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP072 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP011 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP035 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP038 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP050 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
# 1st week - CHG0053334 - AWS01 DEV APRV - AWS01 JAVA Patching - USAWS01LVAPP003 - 2024-02-24 18:00:00 - 2024-02-25 18:00:00 - No - 24 hours - up to 1 hour during reboot
